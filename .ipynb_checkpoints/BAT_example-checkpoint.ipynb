# %%
using Pkg
Pkg.add("BAT")
Pkg.add("Distributions")
Pkg.add("IntervalSets")
Pkg.add("Plots")
Pkg.add("StatsBase")

# %%
using BAT
using Distributions
using IntervalSets
using Plots
using StatsBase

# %% [markdown]
# ## Poisson Counting Example
#
# We want to determine the porperties of a radioactive signal source in the presence of background from natural sources of radioactivity. We assume to have one signal source $S$ and one background source $B$.
#
# ### 1. Background only measurement
# - $k_\text{B} = 10$ counts with detector and without source
# - Determine event rate of natural radioactive background
#
# Define the log-likelihood using the function `logpdf()` and `Poisson()`from `Distributions.jl`.

# %%
# Number of observed background events
k_B = 10

likelihood_B = let k = k_B
    params -> begin
        return LogDVal(logpdf(Poisson(params.λ_B), k))
    end
end
# Out:
# #1 (generic function with 1 method)

# %% [markdown]
# Define the prior with the `NamedTupleDist()` function. We choose a flat prior between 0 and 30.
#
# Afterwards, we use the likelihood and prior to define the `PosteriorDensity()`.

# %%
prior_B = BAT.NamedTupleDist(
    λ_B = Uniform(0, 30)
)

posterior_B = PosteriorDensity(likelihood_B, prior_B);
# Out:
# PosteriorDensity(objectid = 0xdc6f6b64b80fa74e, varshape = NamedTupleShape((:λ_B,)}(…))

# %% [markdown]
# Define the settings for the sampling algorithm: We choose the `MetropolisHastings()` algorithm with $10^6$ samples and $4$ chains.

# %%
algorithm = MetropolisHastings()
nsamples = 10^6
nchains = 4
# Out:
# 4

# %% [markdown]
# Calling `bat_sample()` to explore the parameter space of the posterior.

# %%
samples_B, chains_B = bat_sample(
    posterior_B,
    MCMCSampling(mcalg = algorithm, nsteps = nsamples, nchains = nchains)
);
# Out:
# ┌ Info: Initializing new RNG of type Random123.Philox4x{UInt64, 10}
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/algotypes/bat_default.jl:44
# ┌ Info: Using transform algorithm PriorSubstitution()
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/algotypes/bat_default.jl:44
# ┌ Info: Trying to generate 4 viable MCMC chain(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/chain_pool_init.jl:56
# ┌ Info: Selected 4 MCMC chain(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/chain_pool_init.jl:174
# ┌ Info: Begin tuning of 4 MCMC chain(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:38
# ┌ Info: MCMC Tuning cycle 1 finished, 4 chains, 0 tuned, 4 converged.
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:69
# ┌ Info: MCMC Tuning cycle 2 finished, 4 chains, 0 tuned, 4 converged.
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:69
# ┌ Info: MCMC Tuning cycle 3 finished, 4 chains, 4 tuned, 4 converged.
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:69
# ┌ Info: MCMC tuning of 4 chains successful after 3 cycle(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:75
# ┌ Info: Running post-tuning stabilization steps for 4 MCMC chain(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:86
# (result = DensitySampleVector(length = 1300687, varshape = NamedTupleShape((:λ_B,)}(…)), result_trafo = DensitySampleVector(length = 1300687, varshape = ValueShapes.ArrayShape{Float64, 1}((1,))), trafo = DistributionTransform(BAT.StandardMvNormal{Float64}(_dim=1), NamedTupleDist{(:λ_B,)}(…)), generator = MCMCSampleGenerator(MHIterator(id = 3, nsamples = 325765, density = PosteriorDensity(objectid = 0x39b1dfb20c64eb2a, varshape = ValueShapes.ArrayShape{Real, 1}((1,)))), …), isvalid = true, optargs = (rng = Random123.Philox4x{UInt64, 10}(0xedf7e14b4203f484, 0x2357cf3bdf5df1fa, 0x857c6d781c9a8a9a, 0x749d066c2ca77270, 0x096132dbfca31dc0, 0x59c52860dcd05ff4, 0x0000000000000000, 0x0000000000000000, 0x0000000000000000, 0x8000020100000000, 1), algorithm = MCMCSampling{MetropolisHastings{BAT.MvTDistProposal, RepetitionWeighting{Int64}, AdaptiveMHTuning}, PriorToGaussian, MCMCChainPoolInit, MCMCMultiCycleBurnin, BrooksGelmanConvergence, typeof(BAT.nop_func)}
#   mcalg: MetropolisHastings{BAT.MvTDistProposal, RepetitionWeighting{Int64}, AdaptiveMHTuning}
#   trafo: PriorToGaussian PriorToGaussian()
#   nchains: Int64 4
#   nsteps: Int64 1000000
#   init: MCMCChainPoolInit
#   burnin: MCMCMultiCycleBurnin
#   convergence: BrooksGelmanConvergence
#   strict: Bool true
#   store_burnin: Bool false
#   nonzero_weights: Bool true
#   callback: nop_func (function of type typeof(BAT.nop_func))
# ), kwargs = NamedTuple())

# %% [markdown]
# Print some statistics of the samples.

# %%
sd_B = SampledDensity(posterior_B, samples_B)
display(sd_B)
# Out:
# BAT.jl - SampledDensity
# ──────────────────────────────
#
# Sampling:
# ─────────────────────────
# total number of samples:      1300687
# effective number of samples: (λ_B = 571365.1387807722,)
#
#
# Parameter estimates:
# ─────────────────────────
# number of free parameters: 1
#
# NamedTuple{(:parameter, :mean, :std, :global_mode, :marginal_mode), Tuple{Symbol, Float64, Float64, Float64, Float64}}[(parameter = :λ_B, mean = 10.997129865839263, std = 3.308963159194144, global_mode = 9.9999986006577, marginal_mode = 10.1)]
#
#
# Covariance matrix:
# ─────────────────────────
# 1×1 Named Matrix{Float64}
# cov ╲  │     λ_B
# ───────┼────────
# λ_B    │ 10.9492

# %% [markdown]
# Take a look at the resulting distribution of the background rate using `plot()`.

# %%
plot(samples_B, :λ_B)
plot!(prior_B, label = "Prior")
xlabel!("\$\\lambda_B\$")
ylabel!("\$p(\\lambda_B)\$")

# %% [markdown]
# ### 2. Signal + Background
#
# - $k_{\text{S+B}} = 12$ counts using the radioactive source in the setup
# - Determine the signal rate $\lambda_{\text{S}}$ using the knowledge about the background
#
# Define the likelihood for the signal + background model.

# %%
# Number of observed events
k_SB = 12

likelihood_SB = let k = k_SB
    params -> begin
        return LogDVal(logpdf(Poisson(params.λ_B + params.λ_S), k))
    end
end
# Out:
# #3 (generic function with 1 method)

# %% [markdown]
# Define the prior for both the signal and background parameters. The signal prior is chosen flat, while we take the background prior as distribution from the previous measurement.

# %%
hist_B = fit(Histogram, 
    BAT.flatview(samples_B.v.λ_B), 
    BAT.FrequencyWeights(BAT.flatview(samples_B.weight)), 
    nbins = 400
)
# Out:
# Histogram{Int64, 1, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}}}
# edges:
#   1.7:0.1:30.0
# weights: [1, 7, 23, 4, 14, 31, 46, 68, 123, 111  …  9, 9, 9, 8, 10, 9, 9, 5, 11, 1]
# closed: left
# isdensity: false

# %%
prior_SB = BAT.NamedTupleDist(
    # λ_B = hist_B,
    λ_B = 0..30,
    λ_S = 0..30
)

posterior_SB = PosteriorDensity(likelihood_SB, prior_SB)

samples_SB, chains_SB = bat_sample(posterior_SB,
    MCMCSampling(mcalg = algorithm, nsteps = nsamples, nchains = nchains)
);
# Out:
# ┌ Info: Initializing new RNG of type Random123.Philox4x{UInt64, 10}
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/algotypes/bat_default.jl:44
# ┌ Info: Using transform algorithm PriorSubstitution()
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/algotypes/bat_default.jl:44
# ┌ Info: Trying to generate 4 viable MCMC chain(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/chain_pool_init.jl:56
# ┌ Info: Selected 4 MCMC chain(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/chain_pool_init.jl:174
# ┌ Info: Begin tuning of 4 MCMC chain(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:38
# ┌ Info: MCMC Tuning cycle 1 finished, 4 chains, 0 tuned, 4 converged.
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:69
# ┌ Info: MCMC Tuning cycle 2 finished, 4 chains, 4 tuned, 4 converged.
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:69
# ┌ Info: MCMC tuning of 4 chains successful after 2 cycle(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:75
# ┌ Info: Running post-tuning stabilization steps for 4 MCMC chain(s).
# └ @ BAT /Users/larsroehrig/.julia/dev/BAT.jl/src/samplers/mcmc/multi_cycle_burnin.jl:86
# (result = DensitySampleVector(length = 1087243, varshape = NamedTupleShape((:λ_B, :λ_S)}(…)), result_trafo = DensitySampleVector(length = 1087243, varshape = ValueShapes.ArrayShape{Float64, 1}((2,))), trafo = DistributionTransform(BAT.StandardMvNormal{Float64}(_dim=2), NamedTupleDist{(:λ_B, :λ_S)}(…)), generator = MCMCSampleGenerator(MHIterator(id = 4, nsamples = 271217, density = PosteriorDensity(objectid = 0x8860c7ce291a5ebe, varshape = ValueShapes.ArrayShape{Real, 1}((2,)))), …), isvalid = true, optargs = (rng = Random123.Philox4x{UInt64, 10}(0xe319c7ca3a11258e, 0xb530ce214369b77e, 0x79e8e6adc9390e15, 0x07b4b6679f8fc06a, 0x05913f691352b7e1, 0xbb2b02e6fa29023b, 0x0000000000000000, 0x0000000000000000, 0x0000000000000000, 0x8000020100000000, 2), algorithm = MCMCSampling{MetropolisHastings{BAT.MvTDistProposal, RepetitionWeighting{Int64}, AdaptiveMHTuning}, PriorToGaussian, MCMCChainPoolInit, MCMCMultiCycleBurnin, BrooksGelmanConvergence, typeof(BAT.nop_func)}
#   mcalg: MetropolisHastings{BAT.MvTDistProposal, RepetitionWeighting{Int64}, AdaptiveMHTuning}
#   trafo: PriorToGaussian PriorToGaussian()
#   nchains: Int64 4
#   nsteps: Int64 1000000
#   init: MCMCChainPoolInit
#   burnin: MCMCMultiCycleBurnin
#   convergence: BrooksGelmanConvergence
#   strict: Bool true
#   store_burnin: Bool false
#   nonzero_weights: Bool true
#   callback: nop_func (function of type typeof(BAT.nop_func))
# ), kwargs = NamedTuple())

# %%
plot(samples_SB, 
    param_labels=["\\lambda_B", "\\lambda_S"]
)

# %% [markdown]
# Again, some statistics.

# %%
println("Mode: $(mode(samples_SB))")
println("Mean: $(mean(samples_SB))")
println("Variance: $(var(samples_SB))")
println("Standard Deviation: λ_B = $(sqrt(var(samples_SB).λ_B[1])), λ_S = $(sqrt(var(samples_SB).λ_S[1]))")
# Out:
# Mode: (λ_B = 10.485488346327257, λ_S = 1.5145142388674238)
# Mean: (λ_B = 6.999666459566542, λ_S = 6.999366969370634)
# Variance: (λ_B = 21.006602079023075, λ_S = 20.988800227550584)
# Standard Deviation: λ_B = 4.583295984226098, λ_S = 4.581353536625457
